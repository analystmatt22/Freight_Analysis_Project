# %%
import pandas as pd
import numpy as np

# %%
X_order = pd.read_csv('/Users/deepakmathew/Desktop/Data Sheet - Coin/Order Report-X-Table 1.csv')
X_order.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ExternOrderNo  400 non-null    int64
#  1   SKU            400 non-null    object
#  2   Order Qty      400 non-null    float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 9.5+ KB

# %%
X_order
# Out:
#      ExternOrderNo            SKU  Order Qty
# 0       2001806210  8904223816214        1.0
# 1       2001806210  8904223818874        1.0
# 2       2001806226  8904223818850        2.0
# 3       2001806229  8904223818706        1.0
# 4       2001806229  8904223818850        1.0
# ..             ...            ...        ...
# 395     2001827036  8904223819093        1.0
# 396     2001827036  8904223819109        1.0
# 397     2001827036  8904223819277        1.0
# 398     2001827036  GIFTBOX202002        1.0
# 399     2001827036     SACHETS001        1.0
#
# [400 rows x 3 columns]

# %%
X_order.isnull().sum()
# Out:
# ExternOrderNo    0
# SKU              0
# Order Qty        0
# dtype: int64

# %%
X_order['SKU'].nunique()
# Out:
# 65

# %%
X_SKU_weight = pd.read_csv('/Users/deepakmathew/Desktop/Data Sheet - Coin/SKU & Weight - X-Table 1.csv')
X_SKU_weight.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67 entries, 0 to 66
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   SKU         67 non-null     object
#  1   Weight      67 non-null     object
#  2   Unnamed: 2  0 non-null      float64
#  3   Unnamed: 3  0 non-null      float64
#  4   Unnamed: 4  0 non-null      float64
# dtypes: float64(3), object(2)
# memory usage: 2.7+ KB

# %%
X_SKU_weight
# Out:
#               SKU      Weight  Unnamed: 2  Unnamed: 3  Unnamed: 4
# 0   8904223815682         210         NaN         NaN         NaN
# 1   8904223815804         160         NaN         NaN         NaN
# 2   8904223815859         165         NaN         NaN         NaN
# 3   8904223815866         113         NaN         NaN         NaN
# 4   8904223815873          65         NaN         NaN         NaN
# ..            ...         ...         ...         ...         ...
# 62  GIFTBOX202002         500         NaN         NaN         NaN
# 63  GIFTBOX202003         500         NaN         NaN         NaN
# 64  GIFTBOX202004         500         NaN         NaN         NaN
# 65     SACHETS001          10         NaN         NaN         NaN
# 66            SKU  Weight (g)         NaN         NaN         NaN
#
# [67 rows x 5 columns]

# %%
#varname.drop(['colnameA', 'colnameB'], axis='columns', inplace=True)

X_SKU_weight.drop(['Unnamed: 2','Unnamed: 3','Unnamed: 4'], axis='columns', inplace=True)

# %%
X_SKU_weight.head()
# Out:
#              SKU Weight
# 0  8904223815682    210
# 1  8904223815804    160
# 2  8904223815859    165
# 3  8904223815866    113
# 4  8904223815873     65

# %%
X_SKU_weight['SKU'].nunique()
# Out:
# 66

# %%
X_Pincode = pd.read_csv('/Users/deepakmathew/Desktop/Data Sheet - Coin/Pincode & Zone - X-Table 1.csv')
X_Pincode.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 124 entries, 0 to 123
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Warehouse Pincode  124 non-null    int64
#  1   Customer Pincode   124 non-null    int64
#  2   Zone               124 non-null    object
#  3   Unnamed: 3         0 non-null      float64
#  4   Unnamed: 4         0 non-null      float64
# dtypes: float64(2), int64(2), object(1)
# memory usage: 5.0+ KB

# %%
X_order["SKU_weight"] = "" #Create empty column.
print(X_order)
# Out:
#      ExternOrderNo            SKU  Order Qty SKU_weight
# 0       2001806210  8904223816214        1.0
# 1       2001806210  8904223818874        1.0
# 2       2001806226  8904223818850        2.0
# 3       2001806229  8904223818706        1.0
# 4       2001806229  8904223818850        1.0
# ..             ...            ...        ...        ...
# 395     2001827036  8904223819093        1.0
# 396     2001827036  8904223819109        1.0
# 397     2001827036  8904223819277        1.0
# 398     2001827036  GIFTBOX202002        1.0
# 399     2001827036     SACHETS001        1.0
#
# [400 rows x 4 columns]

# %%
X_order.head()
# Out:
#    ExternOrderNo            SKU  Order Qty SKU_weight
# 0     2001806210  8904223816214        1.0
# 1     2001806210  8904223818874        1.0
# 2     2001806226  8904223818850        2.0
# 3     2001806229  8904223818706        1.0
# 4     2001806229  8904223818850        1.0

# %%
X_SKU_weight.head()
# Out:
#              SKU Weight
# 0  8904223815682    210
# 1  8904223815804    160
# 2  8904223815859    165
# 3  8904223815866    113
# 4  8904223815873     65

# %%
#copying the corresponfing values from different dataframe to current dataframe
#with different row numbers
#X_order_new = X_order.set_index('SKU').combine_first(X_SKU_weight.set_index('SKU')).reset_index()

# %%
X_order_new = X_order.set_index('SKU').combine_first(X_SKU_weight.set_index('SKU')).reset_index()
X_order_new.drop('SKU_weight', inplace=True, axis=1)
X_order_new
# Out:
#                SKU  ExternOrderNo  Order Qty      Weight
# 0    8904223815682   2.001809e+09        1.0         210
# 1    8904223815804   2.001807e+09        1.0         160
# 2    8904223815859   2.001808e+09        1.0         165
# 3    8904223815859   2.001809e+09        1.0         165
# 4    8904223815859   2.001809e+09        1.0         165
# ..             ...            ...        ...         ...
# 397  GIFTBOX202004   2.001810e+09        1.0         500
# 398     SACHETS001   2.001819e+09        1.0          10
# 399     SACHETS001   2.001825e+09        1.0          10
# 400     SACHETS001   2.001827e+09        1.0          10
# 401            SKU            NaN        NaN  Weight (g)
#
# [402 rows x 4 columns]

# %%
X_order_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 402 entries, 0 to 401
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SKU            402 non-null    object
#  1   ExternOrderNo  401 non-null    float64
#  2   Order Qty      401 non-null    float64
#  3   Weight         402 non-null    object
# dtypes: float64(2), object(2)
# memory usage: 12.7+ KB

# %%
#To numeric method:
#X_order_new['Weight'] = pd.to_numeric(X_order_new['Weight'],errors='coerce')

# %%
X_order_new['Weight'] = pd.to_numeric(X_order_new['Weight'],errors='coerce')
X_order_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 402 entries, 0 to 401
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SKU            402 non-null    object
#  1   ExternOrderNo  401 non-null    float64
#  2   Order Qty      401 non-null    float64
#  3   Weight         401 non-null    float64
# dtypes: float64(3), object(1)
# memory usage: 12.7+ KB

# %%
#Multiplication
#X_order_new['SKU_price_actual'] = X_order_new['Order Qty']*X_order_new['Weight']

# %%
X_order_new['SKU_price_actual'] = X_order_new['Order Qty']*X_order_new['Weight']
X_order_new
# Out:
#                SKU  ExternOrderNo  Order Qty  Weight  SKU_price_actual
# 0    8904223815682   2.001809e+09        1.0   210.0             210.0
# 1    8904223815804   2.001807e+09        1.0   160.0             160.0
# 2    8904223815859   2.001808e+09        1.0   165.0             165.0
# 3    8904223815859   2.001809e+09        1.0   165.0             165.0
# 4    8904223815859   2.001809e+09        1.0   165.0             165.0
# ..             ...            ...        ...     ...               ...
# 397  GIFTBOX202004   2.001810e+09        1.0   500.0             500.0
# 398     SACHETS001   2.001819e+09        1.0    10.0              10.0
# 399     SACHETS001   2.001825e+09        1.0    10.0              10.0
# 400     SACHETS001   2.001827e+09        1.0    10.0              10.0
# 401            SKU            NaN        NaN     NaN               NaN
#
# [402 rows x 5 columns]

# %%
X_order_new.head(10)
# Out:
#              SKU  ExternOrderNo  Order Qty  Weight  SKU_price_actual
# 0  8904223815682   2.001809e+09        1.0   210.0             210.0
# 1  8904223815804   2.001807e+09        1.0   160.0             160.0
# 2  8904223815859   2.001808e+09        1.0   165.0             165.0
# 3  8904223815859   2.001809e+09        1.0   165.0             165.0
# 4  8904223815859   2.001809e+09        1.0   165.0             165.0
# 5  8904223815859   2.001811e+09        1.0   165.0             165.0
# 6  8904223815859   2.001811e+09        1.0   165.0             165.0
# 7  8904223815859   2.001821e+09        1.0   165.0             165.0
# 8  8904223815866   2.001809e+09        1.0   113.0             113.0
# 9  8904223815866   2.001809e+09        2.0   113.0             226.0

# %%
X_order_new.rename(columns={'ExternOrderNo':'Order ID','Weight':'Total Weight X',
                                          'SKU_price_actual':'Expected Charge'}, inplace=True)

# %%
X_order_new
# Out:
#                SKU      Order ID  Order Qty  Total Weight X  Expected Charge
# 0    8904223815682  2.001809e+09        1.0           210.0            210.0
# 1    8904223815804  2.001807e+09        1.0           160.0            160.0
# 2    8904223815859  2.001808e+09        1.0           165.0            165.0
# 3    8904223815859  2.001809e+09        1.0           165.0            165.0
# 4    8904223815859  2.001809e+09        1.0           165.0            165.0
# ..             ...           ...        ...             ...              ...
# 397  GIFTBOX202004  2.001810e+09        1.0           500.0            500.0
# 398     SACHETS001  2.001819e+09        1.0            10.0             10.0
# 399     SACHETS001  2.001825e+09        1.0            10.0             10.0
# 400     SACHETS001  2.001827e+09        1.0            10.0             10.0
# 401            SKU           NaN        NaN             NaN              NaN
#
# [402 rows x 5 columns]

# %%
X_order_new.isnull().sum()
# Out:
# SKU                0
# Order ID           1
# Order Qty          1
# Total Weight X     1
# Expected Charge    1
# dtype: int64

# %%
X_order_new.dropna(inplace=True)

# %%
X_order_new.isnull().sum()
# Out:
# SKU                0
# Order ID           0
# Order Qty          0
# Total Weight X     0
# Expected Charge    0
# dtype: int64

# %%
X_order_new.rename(columns={'Total Weight X':'Weight',
                                          'Expected Charge':'Actual Weight'}, inplace=True)

# %%
X_order_new
# Out:
#                SKU      Order ID  Order Qty  Weight  Actual Weight
# 0    8904223815682  2.001809e+09        1.0   210.0          210.0
# 1    8904223815804  2.001807e+09        1.0   160.0          160.0
# 2    8904223815859  2.001808e+09        1.0   165.0          165.0
# 3    8904223815859  2.001809e+09        1.0   165.0          165.0
# 4    8904223815859  2.001809e+09        1.0   165.0          165.0
# ..             ...           ...        ...     ...            ...
# 396  GIFTBOX202003  2.001813e+09        1.0   500.0          500.0
# 397  GIFTBOX202004  2.001810e+09        1.0   500.0          500.0
# 398     SACHETS001  2.001819e+09        1.0    10.0           10.0
# 399     SACHETS001  2.001825e+09        1.0    10.0           10.0
# 400     SACHETS001  2.001827e+09        1.0    10.0           10.0
#
# [401 rows x 5 columns]

# %%
#df['a'] *= 10

# %%
X_order_new['Weight'] /= 1000

# %%
X_order_new.head(2)
# Out:
#              SKU      Order ID  Order Qty  Weight  Actual Weight
# 0  8904223815682  2.001809e+09        1.0    0.21          210.0
# 1  8904223815804  2.001807e+09        1.0    0.16          160.0

# %%
X_order_new.drop('Actual Weight', inplace=True, axis=1)

# %%
X_order_new
# Out:
#                SKU      Order ID  Order Qty  Weight
# 0    8904223815682  2.001809e+09        1.0   0.210
# 1    8904223815804  2.001807e+09        1.0   0.160
# 2    8904223815859  2.001808e+09        1.0   0.165
# 3    8904223815859  2.001809e+09        1.0   0.165
# 4    8904223815859  2.001809e+09        1.0   0.165
# ..             ...           ...        ...     ...
# 396  GIFTBOX202003  2.001813e+09        1.0   0.500
# 397  GIFTBOX202004  2.001810e+09        1.0   0.500
# 398     SACHETS001  2.001819e+09        1.0   0.010
# 399     SACHETS001  2.001825e+09        1.0   0.010
# 400     SACHETS001  2.001827e+09        1.0   0.010
#
# [401 rows x 4 columns]

# %%
X_order_new['Weight_X'] = X_order_new['Order Qty']*X_order_new['Weight']
X_order_new
# Out:
#                SKU      Order ID  Order Qty  Weight  Weight_X
# 0    8904223815682  2.001809e+09        1.0   0.210     0.210
# 1    8904223815804  2.001807e+09        1.0   0.160     0.160
# 2    8904223815859  2.001808e+09        1.0   0.165     0.165
# 3    8904223815859  2.001809e+09        1.0   0.165     0.165
# 4    8904223815859  2.001809e+09        1.0   0.165     0.165
# ..             ...           ...        ...     ...       ...
# 396  GIFTBOX202003  2.001813e+09        1.0   0.500     0.500
# 397  GIFTBOX202004  2.001810e+09        1.0   0.500     0.500
# 398     SACHETS001  2.001819e+09        1.0   0.010     0.010
# 399     SACHETS001  2.001825e+09        1.0   0.010     0.010
# 400     SACHETS001  2.001827e+09        1.0   0.010     0.010
#
# [401 rows x 5 columns]

# %%
X_order_new.keys()
# Out:
# Index(['SKU', 'Order ID', 'Order Qty', 'Weight', 'Weight_X'], dtype='object')

# %%
X_order_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 401 entries, 0 to 400
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   SKU        401 non-null    object
#  1   Order ID   401 non-null    float64
#  2   Order Qty  401 non-null    float64
#  3   Weight     401 non-null    float64
#  4   Weight_X   401 non-null    float64
# dtypes: float64(4), object(1)
# memory usage: 18.8+ KB

# %%
#Finding number of counts w r to one condition

X_order_new[X_order_new['Weight_X'].values>0.5].count()
# Out:
# SKU          13
# Order ID     13
# Order Qty    13
# Weight       13
# Weight_X     13
# dtype: int64

# %%
#condition for rounding up figures

# %%
Courier_report = pd.read_excel('/Users/deepakmathew/Downloads/Cointab Data Analyst - Challenge/Courier Company - Invoice.xlsx')
Courier_report
# Out:
#           AWB Code    Order ID  Charged Weight  Warehouse Pincode  \
# 0    1091117222124  2001806232            1.30             121003
# 1    1091117222194  2001806273            1.00             121003
# 2    1091117222931  2001806408            2.50             121003
# 3    1091117223244  2001806458            1.00             121003
# 4    1091117229345  2001807012            0.15             121003
# ..             ...         ...             ...                ...
# 119  1091118551656  2001812941            0.73             121003
# 120  1091117614452  2001809383            0.50             121003
# 121  1091120922803  2001820978            0.50             121003
# 122  1091121844806  2001811475            0.50             121003
# 123  1091121846136  2001811305            0.50             121003
#
#      Customer Pincode Zone         Type of Shipment  Billing Amount (Rs.)
# 0              507101    d          Forward charges                 135.0
# ...

# %%
Courier_report.nunique()
# Out:
# AWB Code                124
# Order ID                124
# Charged Weight           54
# Warehouse Pincode         1
# Customer Pincode        108
# Zone                      3
# Type of Shipment          2
# Billing Amount (Rs.)     20
# dtype: int64

# %%
Courier_report.rename(columns={'AWB Code':'AWB Number', 'Charged Weight':'Total weight as per Courier Company (KG)'
                              ,'Zone':'Delivery Zone charged by Courier Company','Billing Amount (Rs.)':'Charges Billed by Courier Company (Rs.)'}, 
                      inplace=True)

# %%
Courier_report
# Out:
#         AWB Number    Order ID  Total weight as per Courier Company (KG)  \
# 0    1091117222124  2001806232                                      1.30
# 1    1091117222194  2001806273                                      1.00
# 2    1091117222931  2001806408                                      2.50
# 3    1091117223244  2001806458                                      1.00
# 4    1091117229345  2001807012                                      0.15
# ..             ...         ...                                       ...
# 119  1091118551656  2001812941                                      0.73
# 120  1091117614452  2001809383                                      0.50
# 121  1091120922803  2001820978                                      0.50
# 122  1091121844806  2001811475                                      0.50
# 123  1091121846136  2001811305                                      0.50
#
#      Warehouse Pincode  Customer Pincode  \
# 0               121003            507101
# ...

# %%
#rslt_df = details.sort_values(by = 'Name')

#Courier_report = Courier_report.sort_values(by='Order ID')

# %%
X_order_new.head(2)
# Out:
#              SKU      Order ID  Order Qty  Weight  Weight_X
# 0  8904223815682  2.001809e+09        1.0    0.21      0.21
# 1  8904223815804  2.001807e+09        1.0    0.16      0.16

# %%
Courier_report.head(2)
# Out:
#       AWB Number    Order ID  Total weight as per Courier Company (KG)  \
# 0  1091117222124  2001806232                                       1.3
# 1  1091117222194  2001806273                                       1.0
#
#    Warehouse Pincode  Customer Pincode  \
# 0             121003            507101
# 1             121003            486886
#
#   Delivery Zone charged by Courier Company Type of Shipment  \
# 0                                        d  Forward charges
# 1                                        d  Forward charges
#
#    Charges Billed by Courier Company (Rs.)
# 0                                    135.0
# 1                                     90.2

# %%
#variable name.to_csv('path of file.csv')

X_order_new.to_csv('/Users/deepakmathew/Downloads/Cointab Data Analyst - Challenge/X1.csv')

# %%
X_order_new['Order ID'].nunique()
# Out:
# 124

# %%
Courier_report['Order ID'].nunique()
# Out:
# 124

# %%
#Hence proved that order id has 124 unique values in both datasets of X and the courier
#Hence we need to make a new column with added weights of unique order id's in X dataset

# %%
X_order_new.head(2)
# Out:
#              SKU      Order ID  Order Qty  Weight  Weight_X
# 0  8904223815682  2.001809e+09        1.0    0.21      0.21
# 1  8904223815804  2.001807e+09        1.0    0.16      0.16

# %%
#Found the sum of weights of unique order id in the excel sheet and created a new one
#https://www.mrexcel.com/board/threads/sum-cells-based-on-their-id-number.835871/

# %%
Xsheet_new = pd.read_csv('/Users/deepakmathew/Desktop/Coin2/Xsheet_new.csv')
Xsheet_new.keys()
# Out:
# Index(['Order ID', 'Unique sum of weights'], dtype='object')

# %%
Courier_report.shape
# Out:
# (124, 8)

# %%
#X_order_new
#Courier_report
#Xsheet_new

# %%
Courier_report_1 = Courier_report.set_index('Order ID').combine_first(Xsheet_new.set_index('Order ID')).reset_index()

# %%
Courier_report_1.shape
# Out:
# (124, 9)

# %%
Courier_report.head(2)
# Out:
#       AWB Number    Order ID  Total weight as per Courier Company (KG)  \
# 0  1091117222124  2001806232                                       1.3
# 1  1091117222194  2001806273                                       1.0
#
#    Warehouse Pincode  Customer Pincode  \
# 0             121003            507101
# 1             121003            486886
#
#   Delivery Zone charged by Courier Company Type of Shipment  \
# 0                                        d  Forward charges
# 1                                        d  Forward charges
#
#    Charges Billed by Courier Company (Rs.)
# 0                                    135.0
# 1                                     90.2

# %%
Courier_report_1.head(2)
# Out:
#      Order ID     AWB Number  Charges Billed by Courier Company (Rs.)  \
# 0  2001806210  1091117221940                                    174.5
# 1  2001806226  1091117222065                                     90.2
#
#    Customer Pincode Delivery Zone charged by Courier Company  \
# 0            140604                                        b
# 1            723146                                        d
#
#    Total weight as per Courier Company (KG) Type of Shipment  \
# 0                                      2.92  Forward charges
# 1                                      0.68  Forward charges
#
#    Unique sum of weights  Warehouse Pincode
# 0                   0.22             121003
# 1                   0.48             121003

# %%
Courier_report_1.rename(columns={'Unique sum of weights':'Total weight as per X (KG)'}, inplace=True)
Courier_report_1.head(2)
# Out:
#      Order ID     AWB Number  Charges Billed by Courier Company (Rs.)  \
# 0  2001806210  1091117221940                                    174.5
# 1  2001806226  1091117222065                                     90.2
#
#    Customer Pincode Delivery Zone charged by Courier Company  \
# 0            140604                                        b
# 1            723146                                        d
#
#    Total weight as per Courier Company (KG) Type of Shipment  \
# 0                                      2.92  Forward charges
# 1                                      0.68  Forward charges
#
#    Total weight as per X (KG)  Warehouse Pincode
# 0                        0.22             121003
# 1                        0.48             121003

# %%
Courier_report_1.to_csv('/Users/deepakmathew/Downloads/Courier_report_1.csv')

# %%
#https://www.ablebits.com/office-addins-blog/2015/08/06/excel-round-functions/#CEILING-function

# %%
Courier_report_1['Customer Pincode'].nunique()
# Out:
# 108

# %%
Xcode = pd.read_excel('/Users/deepakmathew/Downloads/Cointab Data Analyst - Challenge/Company X - Pincode Zones.xlsx')
Xcode.head()
# Out:
#    Warehouse Pincode  Customer Pincode Zone
# 0             121003            507101    d
# 1             121003            486886    d
# 2             121003            532484    d
# 3             121003            143001    b
# 4             121003            515591    d

# %%
Xcode['Zone'].unique()
# Out:
# array(['d', 'b', 'e'], dtype=object)

# %%
Xcode.shape
# Out:
# (124, 3)

# %%
Courier_report_1.groupby('Type of Shipment')['Delivery Zone charged by Courier Company'].unique()
# Out:
# Type of Shipment
# Forward and RTO charges    [d, e, b]
# Forward charges               [b, d]
# Name: Delivery Zone charged by Courier Company, dtype: object

# %%
#Pending part was done in the excel sheet
